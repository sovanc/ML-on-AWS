# %%
import boto3
import json 

if __name__ == "__main__":
    imageFile = 'Star-Wars.jpg'
    client = boto3.client('rekognition')
    
    with open(imageFile, 'rb') as image:
        response = client.detect_faces(Image = {'Bytes': image.read()})
    
    print('Detected faces for ' + imageFile)
    for faceDetail in response['FaceDetails']:
        print('Here are the attributes:')
        print(json.dumps(faceDetail, indent=4, sort_keys=True))
    
    print('...\n')
    print('What do you think, heh?')
# Out:
# Detected faces for Star-Wars.jpg
# Here are the attributes:
# {
#     "BoundingBox": {
#         "Height": 0.2382255494594574,
#         "Left": 0.3127327263355255,
#         "Top": 0.4896470010280609,
#         "Width": 0.09328696131706238
#     },
#     "Confidence": 99.99998474121094,
#     "Landmarks": [
#         {
#             "Type": "eyeLeft",
#             "X": 0.3476376533508301,
#             "Y": 0.5839638113975525
#         },
#         {
#             "Type": "eyeRight",
#             "X": 0.3905559778213501,
#             "Y": 0.5839565396308899
#         },
#         {
#             "Type": "mouthLeft",
#             "X": 0.3509158194065094,
#             "Y": 0.6679463386535645
#         },
#         {
#             "Type": "mouthRight",
#             "X": 0.38661813735961914,
#             "Y": 0.6678117513656616
#         },
#         {
#             "Type": "nose",
#             "X": 0.37406739592552185,
#             "Y": 0.6323621273040771
#         }
#     ],
#     "Pose": {
#         "Pitch": -16.520639419555664,
#         "Roll": -0.00672712828963995,
#         "Yaw": -1.1060433387756348
#     },
#     "Quality": {
#         "Brightness": 54.10489273071289,
#         "Sharpness": 96.61495208740234
#     }
# }
# Here are the attributes:
# {
#     "BoundingBox": {
#         "Height": 0.2189585417509079,
#         "Left": 0.6806018352508545,
#         "Top": 0.32672983407974243,
#         "Width": 0.08628350496292114
#     },
#     "Confidence": 99.9999771118164,
#     "Landmarks": [
#         {
#             "Type": "eyeLeft",
#             "X": 0.7050480842590332,
#             "Y": 0.4043767750263214
#         },
#         {
#             "Type": "eyeRight",
#             "X": 0.7406540513038635,
#             "Y": 0.42319679260253906
#         },
#         {
#             "Type": "mouthLeft",
#             "X": 0.6968464851379395,
#             "Y": 0.48755329847335815
#         },
#         {
#             "Type": "mouthRight",
#             "X": 0.7260614037513733,
#             "Y": 0.503186047077179
#         },
#         {
#             "Type": "nose",
#             "X": 0.7137519121170044,
#             "Y": 0.45948681235313416
#         }
#     ],
#     "Pose": {
#         "Pitch": 2.107680082321167,
#         "Roll": 16.779552459716797,
#         "Yaw": 20.358112335205078
#     },
#     "Quality": {
#         "Brightness": 59.00933074951172,
#         "Sharpness": 92.22801208496094
#     }
# }
# Here are the attributes:
# {
#     "BoundingBox": {
#         "Height": 0.21429239213466644,
#         "Left": 0.5737185478210449,
#         "Top": 0.455219030380249,
#         "Width": 0.08691740036010742
#     },
#     "Confidence": 99.99993896484375,
#     "Landmarks": [
#         {
#             "Type": "eyeLeft",
#             "X": 0.610072910785675,
#             "Y": 0.5287951827049255
#         },
#         {
#             "Type": "eyeRight",
#             "X": 0.6464234590530396,
#             "Y": 0.5405714511871338
#         },
#         {
#             "Type": "mouthLeft",
#             "X": 0.6086238622665405,
#             "Y": 0.6097677946090698
#         },
#         {
#             "Type": "mouthRight",
#             "X": 0.6385031938552856,
#             "Y": 0.6194970607757568
#         },
#         {
#             "Type": "nose",
#             "X": 0.631730854511261,
#             "Y": 0.572771430015564
#         }
#     ],
#     "Pose": {
#         "Pitch": 8.0979642868042,
#         "Roll": 10.32801628112793,
#         "Yaw": 21.310068130493164
#     },
#     "Quality": {
#         "Brightness": 75.2498779296875,
#         "Sharpness": 96.61495208740234
#     }
# }
# Here are the attributes:
# {
#     "BoundingBox": {
#         "Height": 0.2037813514471054,
#         "Left": 0.43255579471588135,
#         "Top": 0.6069507002830505,
#         "Width": 0.08412718772888184
#     },
#     "Confidence": 99.99990844726562,
#     "Landmarks": [
#         {
#             "Type": "eyeLeft",
#             "X": 0.45449188351631165,
#             "Y": 0.6755967140197754
#         },
#         {
#             "Type": "eyeRight",
#             "X": 0.48977574706077576,
#             "Y": 0.6905348300933838
#         },
#         {
#             "Type": "mouthLeft",
#             "X": 0.4487764239311218,
#             "Y": 0.7525458931922913
#         },
#         {
#             "Type": "mouthRight",
#             "X": 0.4778493642807007,
#             "Y": 0.7651504278182983
#         },
#         {
#             "Type": "nose",
#             "X": 0.46167221665382385,
#             "Y": 0.7208908200263977
#         }
#     ],
#     "Pose": {
#         "Pitch": 2.4732167720794678,
#         "Roll": 10.450952529907227,
#         "Yaw": -22.611148834228516
#     },
#     "Quality": {
#         "Brightness": 67.56486511230469,
#         "Sharpness": 94.08262634277344
#     }
# }
# Here are the attributes:
# {
#     "BoundingBox": {
#         "Height": 0.21203625202178955,
#         "Left": 0.13764004409313202,
#         "Top": 0.7496596574783325,
#         "Width": 0.08024556934833527
#     },
#     "Confidence": 99.99993133544922,
#     "Landmarks": [
#         {
#             "Type": "eyeLeft",
#             "X": 0.16029326617717743,
#             "Y": 0.8455514907836914
#         },
#         {
#             "Type": "eyeRight",
#             "X": 0.19661132991313934,
#             "Y": 0.837831437587738
#         },
#         {
#             "Type": "mouthLeft",
#             "X": 0.16741704940795898,
#             "Y": 0.9218929409980774
#         },
#         {
#             "Type": "mouthRight",
#             "X": 0.19737593829631805,
#             "Y": 0.9154437780380249
#         },
#         {
#             "Type": "nose",
#             "X": 0.18089142441749573,
#             "Y": 0.8853015899658203
#         }
#     ],
#     "Pose": {
#         "Pitch": -0.8360053300857544,
#         "Roll": -5.257071495056152,
#         "Yaw": 1.997575283050537
#     },
#     "Quality": {
#         "Brightness": 50.07564926147461,
#         "Sharpness": 92.22801208496094
#     }
# }
# ...
#
# What do you think, heh?
