# %%
import boto3
import json

comprehend = boto3.client(service_name='comprehend', region_name='us-east-1')
text = "I love Canada and her people. A wonderful place to live."

print('Calling DetectSyntax')
print(json.dumps(comprehend.detect_syntax(Text=text, LanguageCode='en'), sort_keys=True, indent=4))
print('End of DetectSyntax\n')
# Out:
# Calling DetectSyntax
# {
#     "ResponseMetadata": {
#         "HTTPHeaders": {
#             "content-length": "1528",
#             "content-type": "application/x-amz-json-1.1",
#             "date": "Wed, 25 Sep 2019 02:09:41 GMT",
#             "x-amzn-requestid": "c4bba0e5-d5d4-4469-8f4d-4b645ce831c1"
#         },
#         "HTTPStatusCode": 200,
#         "RequestId": "c4bba0e5-d5d4-4469-8f4d-4b645ce831c1",
#         "RetryAttempts": 0
#     },
#     "SyntaxTokens": [
#         {
#             "BeginOffset": 0,
#             "EndOffset": 1,
#             "PartOfSpeech": {
#                 "Score": 0.9999672174453735,
#                 "Tag": "PRON"
#             },
#             "Text": "I",
#             "TokenId": 1
#         },
#         {
#             "BeginOffset": 2,
#             "EndOffset": 6,
#             "PartOfSpeech": {
#                 "Score": 0.9999580383300781,
#                 "Tag": "VERB"
#             },
#             "Text": "love",
#             "TokenId": 2
#         },
#         {
#             "BeginOffset": 7,
#             "EndOffset": 13,
#             "PartOfSpeech": {
#                 "Score": 0.9991426467895508,
#                 "Tag": "PROPN"
#             },
#             "Text": "Canada",
#             "TokenId": 3
#         },
#         {
#             "BeginOffset": 14,
#             "EndOffset": 17,
#             "PartOfSpeech": {
#                 "Score": 0.9999818801879883,
#                 "Tag": "CONJ"
#             },
#             "Text": "and",
#             "TokenId": 4
#         },
#         {
#             "BeginOffset": 18,
#             "EndOffset": 21,
#             "PartOfSpeech": {
#                 "Score": 0.999988317489624,
#                 "Tag": "PRON"
#             },
#             "Text": "her",
#             "TokenId": 5
#         },
#         {
#             "BeginOffset": 22,
#             "EndOffset": 28,
#             "PartOfSpeech": {
#                 "Score": 0.9999780654907227,
#                 "Tag": "NOUN"
#             },
#             "Text": "people",
#             "TokenId": 6
#         },
#         {
#             "BeginOffset": 28,
#             "EndOffset": 29,
#             "PartOfSpeech": {
#                 "Score": 0.999994158744812,
#                 "Tag": "PUNCT"
#             },
#             "Text": ".",
#             "TokenId": 7
#         },
#         {
#             "BeginOffset": 30,
#             "EndOffset": 31,
#             "PartOfSpeech": {
#                 "Score": 0.9997887015342712,
#                 "Tag": "DET"
#             },
#             "Text": "A",
#             "TokenId": 8
#         },
#         {
#             "BeginOffset": 32,
#             "EndOffset": 41,
#             "PartOfSpeech": {
#                 "Score": 0.9996073842048645,
#                 "Tag": "ADJ"
#             },
#             "Text": "wonderful",
#             "TokenId": 9
#         },
#         {
#             "BeginOffset": 42,
#             "EndOffset": 47,
#             "PartOfSpeech": {
#                 "Score": 0.9995610117912292,
#                 "Tag": "NOUN"
#             },
#             "Text": "place",
#             "TokenId": 10
#         },
#         {
#             "BeginOffset": 48,
#             "EndOffset": 50,
#             "PartOfSpeech": {
#                 "Score": 0.99458909034729,
#                 "Tag": "PART"
#             },
#             "Text": "to",
#             "TokenId": 11
#         },
#         {
#             "BeginOffset": 51,
#             "EndOffset": 55,
#             "PartOfSpeech": {
#                 "Score": 0.9997876286506653,
#                 "Tag": "VERB"
#             },
#             "Text": "live",
#             "TokenId": 12
#         },
#         {
#             "BeginOffset": 55,
#             "EndOffset": 56,
#             "PartOfSpeech": {
#                 "Score": 0.999993085861206,
#                 "Tag": "PUNCT"
#             },
#             "Text": ".",
#             "TokenId": 13
#         }
#     ]
# }
# End of DetectSyntax
